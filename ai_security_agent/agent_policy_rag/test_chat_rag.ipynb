# %%
# %pip install langgraph

# %%
from core_logic.rag_engine import PolicyRAGAgent
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from core_logic.rag_engine import PolicyRAGAgent
#
# File d:\HACOM\Code\SENT-System\ai_security_agent\agent_policy_rag\core_logic\rag_engine.py:6
#       4 from langchain_community.vectorstores import Chroma
#       5 from langchain_openai import OpenAIEmbeddings, ChatOpenAI
# ----> 6 from langchain.agents import AgentExecutor, create_tool_calling_agent
#       7 from langchain_core.prompts import ChatPromptTemplate
#       8 from langchain.tools import Tool # Chỉ sử dụng class Tool cốt lõi
#
# ImportError: cannot import name 'AgentExecutor' from 'langchain.agents' (d:\HACOM\Anaconda\Lib\site-packages\langchain\agents\__init__.py)

# %%
#Khởi tạo AI (Không cần truyền API key vào đây nữa)
print("Đang khởi tạo AI Security Agent...")
agent = PolicyRAGAgent(vector_db_path="./vector_db")

# %%
# Giả lập khung chat
print("\n--- HỆ THỐNG ĐÃ SẴN SÀNG ---")
while True:
    user_input = input("Bạn: ")
    if user_input.lower() in ['quit', 'exit', 'thoát']:
        print("AI Agent: Tạm biệt! Hẹn gặp lại.")
        break
    
    print("AI Agent đang suy nghĩ...")
    response = agent.chat(user_input)
    print(f"\n[Kết quả]\nAI Agent: {response}\n")
    print("-" * 50)
