# %%
from core_logic.rag_engine import PolicyRAGAgent

# %%
# 2. Khởi tạo Agent 
print("Đang khởi tạo AI Security Agent...")
agent = PolicyRAGAgent(vector_db_path="./vector_db")

# 3. Vòng lặp chat
print("\n--- HỆ THỐNG ĐÃ SẴN SÀNG ---")
while True:
    user_input = input("Bạn: ")
    if user_input.lower() in ['quit', 'exit', 'thoát']:
        print("AI Agent: Tạm biệt! Hẹn gặp lại.")
        break
    
    print("AI Agent đang suy nghĩ...")
    response = agent.chat(user_input)
    print(f"\n[Kết quả]\nAI Agent: {response}\n")
    print("-" * 50)
# Out:
# Đang khởi tạo AI Security Agent...
#
# --- HỆ THỐNG ĐÃ SẴN SÀNG ---
# d:\HACOM\Anaconda\Lib\site-packages\langchain_google_genai\chat_models.py:2858: UserWarning: HumanMessage with empty content was removed to prevent API error
#   warnings.warn(
# AI Agent đang suy nghĩ...
#
# [Kết quả]
# AI Agent: Lỗi trong quá trình xử lý: contents are required.
#
# --------------------------------------------------
# AI Agent đang suy nghĩ...
# Impersonate 'firefox_133' does not exist, using 'random'
# [Kết quả]
# AI Agent: ISO/IEC 27001:2022 là một tiêu chuẩn quản lý an toàn thông tin, được phát hành chính thức vào ngày 25 tháng 10 năm 2022. Đây là một bản cập nhật vừa phải so với phiên bản trước (ISO 27001:2013).
#
# Những điểm chính của ISO 27001:2022 bao gồm:
#
# *   **Yêu cầu đối với Hệ thống quản lý an toàn thông tin (ISMS):** Tiêu chuẩn này cung cấp các yêu cầu để thiết lập, triển khai, duy trì và cải tiến liên tục một ISMS.
# *   **Khung quản lý rủi ro:** Nó định hướng cách các tổ chức quản lý rủi ro, bảo vệ tài sản và đảm bảo tính liên tục trong hoạt động kinh doanh trước các mối đe dọa.
# *   **Cập nhật các kiểm soát phụ lục:** Phần lớn các thay đổi liên quan đến các kiểm soát trong phụ lục, được điều chỉnh theo các cập nhật của ISO/IEC 27002:2022, đã được xuất bản vào đầu năm 2022.
# *   **Không phải là bản vá kỹ thuật:** Đây là một khuôn khổ kinh doanh, không phải là một bản vá kỹ thuật. Nó tập trung vào cách bạn quản lý rủi ro, bảo vệ tài sản và đảm bảo tính liên tục.
# *   **Quan trọng đối với doanh nghiệp:** Đạt được chứng nhận này giúp phân biệt các doanh nghiệp nghiêm túc với các doanh nghiệp có thể gây ra rủi ro.
#
# Tóm lại, ISO/IEC 27001:2022 là một tiêu chuẩn quan trọng giúp các tổ chức quản lý rủi ro liên quan đến các mối đe dọa an ninh thông tin, bao gồm các chính sách, quy trình và đào tạo nhân viên.
#
# --------------------------------------------------
